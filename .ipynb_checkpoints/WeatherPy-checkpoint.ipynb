# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * when the latitude is below the equiator( 0 Degree Latitude) temperature is high.
# * when the latitude is below the equiator( 0 Degree Latitude) humidity is lower.
# * Not much relation b/w latitude and cloudiness, but i noticed that the below 0 and above 60 shows       less cloud.
# * when the latitude is above 60 shows high wind(above 17.5 mph).
# ---

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import csv
import openweathermapy as owm
from pprint import pprint 

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 636

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
cities_df=pd.DataFrame(cities)
cities_df.columns=["City"]
cities_df['Cloudiness'] = ""
cities_df['Country'] = ""
cities_df['Date'] = ""
cities_df['Humidity'] = ""
cities_df['Lat']=""
cities_df['Lng']=""
cities_df['Max Temp']=""
cities_df['Wind Speed']=""
cities_df.head()
# Out:
#          City Cloudiness Country Date Humidity Lat Lng Max Temp Wind Speed
# 0  vila velha
# 1         gat
# 2   busselton
# 3   ilulissat
# 4        gizo

# %%
#Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

parms = {"units": "metric", "appid": api_key}

for index, row in cities_df.iterrows():
    
    try: 
        weather_data = owm.get_current(row['City'], **parms)
        
        print(f"Processing Record {(index+1)%50} of Set {(index+1)//50+1} | {cities[index]}")
        
        cities_df.loc[index,'Cloudiness'] = weather_data['clouds']['all']
        cities_df.loc[index, 'Country'] = weather_data['sys']['country']
        cities_df.loc[index, 'Date'] = weather_data['dt']
        cities_df.loc[index, 'Humidity'] = weather_data['main']['humidity']
        cities_df.loc[index, 'Lat'] = weather_data['coord']['lat']
        cities_df.loc[index, 'Lng'] = weather_data['coord']['lon']
        cities_df.loc[index, 'Max Temp'] = weather_data['main']['temp_max']
        cities_df.loc[index, 'Wind Speed'] = weather_data['wind']['speed']
        
    except:
        print("City not found... skipping...")
        pass
    
#Indicate that Data Loading is complete
print("----------------------------")
print("Data Retrieval Complete     ")
print("----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | vila velha
# Processing Record 2 of Set 1 | gat
# Processing Record 3 of Set 1 | busselton
# Processing Record 4 of Set 1 | ilulissat
# Processing Record 5 of Set 1 | gizo
# Processing Record 6 of Set 1 | magalia
# Processing Record 7 of Set 1 | atar
# Processing Record 8 of Set 1 | lorengau
# Processing Record 9 of Set 1 | albany
# Processing Record 10 of Set 1 | abha
# Processing Record 11 of Set 1 | upernavik
# Processing Record 12 of Set 1 | lagoa
# Processing Record 13 of Set 1 | yellowknife
# Processing Record 14 of Set 1 | virginia beach
# Processing Record 15 of Set 1 | kudahuvadhoo
# Processing Record 16 of Set 1 | tautira
# Processing Record 17 of Set 1 | calvinia
# Processing Record 18 of Set 1 | glendive
# Processing Record 19 of Set 1 | ixtapa
# Processing Record 20 of Set 1 | auki
# Processing Record 21 of Set 1 | tasiilaq
# Processing Record 22 of Set 1 | sao filipe
# Processing Record 23 of Set 1 | shu
# Processing Record 24 of Set 1 | talakan
# Processing Record 25 of Set 1 | east london
# Processing Record 26 of Set 1 | punta arenas
# Processing Record 27 of Set 1 | aldan
# Processing Record 28 of Set 1 | tiksi
# Processing Record 29 of Set 1 | vangaindrano
# Processing Record 30 of Set 1 | new norfolk
# Processing Record 31 of Set 1 | vaini
# Processing Record 32 of Set 1 | nanortalik
# Processing Record 33 of Set 1 | kayerkan
# Processing Record 34 of Set 1 | kruisfontein
# Processing Record 35 of Set 1 | walvis bay
# Processing Record 36 of Set 1 | qaanaaq
# Processing Record 37 of Set 1 | ponta do sol
# Processing Record 38 of Set 1 | dawlatabad
# Processing Record 39 of Set 1 | rikitea
# Processing Record 40 of Set 1 | hermanus
# Processing Record 41 of Set 1 | teguldet
# Processing Record 42 of Set 1 | conop
# Processing Record 43 of Set 1 | timbiqui
# Processing Record 44 of Set 1 | gushikawa
# Processing Record 45 of Set 1 | gayeri
# Processing Record 46 of Set 1 | haines junction
# Processing Record 47 of Set 1 | vinh
# Processing Record 48 of Set 1 | alyangula
# Processing Record 49 of Set 1 | syasstroy
# City not found... skipping...
# Processing Record 1 of Set 2 | kang
# Processing Record 2 of Set 2 | georgetown
# Processing Record 3 of Set 2 | egvekinot
# Processing Record 4 of Set 2 | ushuaia
# Processing Record 5 of Set 2 | arraial do cabo
# Processing Record 6 of Set 2 | greencastle
# Processing Record 7 of Set 2 | kirakira
# Processing Record 8 of Set 2 | ouadda
# Processing Record 9 of Set 2 | mataura
# Processing Record 10 of Set 2 | grand gaube
# Processing Record 11 of Set 2 | keti bandar
# Processing Record 12 of Set 2 | mount isa
# Processing Record 13 of Set 2 | beyneu
# City not found... skipping...
# City not found... skipping...
# Processing Record 16 of Set 2 | kapaa
# Processing Record 17 of Set 2 | katsuura
# Processing Record 18 of Set 2 | waipawa
# City not found... skipping...
# Processing Record 20 of Set 2 | chokurdakh
# Processing Record 21 of Set 2 | banda aceh
# Processing Record 22 of Set 2 | saint-philippe
# City not found... skipping...
# Processing Record 24 of Set 2 | dikson
# Processing Record 25 of Set 2 | cartagena
# City not found... skipping...
# Processing Record 27 of Set 2 | maceio
# Processing Record 28 of Set 2 | biak
# Processing Record 29 of Set 2 | carnarvon
# Processing Record 30 of Set 2 | adrar
# Processing Record 31 of Set 2 | jalu
# Processing Record 32 of Set 2 | tuktoyaktuk
# Processing Record 11 of Set 4 | isangel
# Processing Record 12 of Set 4 | norman wells
# City not found... skipping...
# Processing Record 14 of Set 4 | alenquer
# Processing Record 15 of Set 4 | bagan
# Processing Record 16 of Set 4 | guerrero negro
# Processing Record 17 of Set 4 | kaitangata
# Processing Record 18 of Set 4 | luanda
# Processing Record 19 of Set 4 | tazovskiy
# Processing Record 20 of Set 4 | bonthe
# Processing Record 21 of Set 4 | severo-kurilsk
# Processing Record 22 of Set 4 | mao
# Processing Record 23 of Set 4 | montrose
# Processing Record 24 of Set 4 | ribeira grande
# Processing Record 25 of Set 4 | fallon
# Processing Record 26 of Set 4 | minab
# Processing Record 27 of Set 4 | sao joao da barra
# Processing Record 28 of Set 4 | puerto ayora
# Processing Record 29 of Set 4 | inhambane
# Processing Record 30 of Set 4 | souillac
# Processing Record 31 of Set 4 | hithadhoo
# Processing Record 32 of Set 4 | merke
# Processing Record 33 of Set 4 | iqaluit
# Processing Record 34 of Set 4 | mar del plata
# Processing Record 35 of Set 4 | mossendjo
# Processing Record 36 of Set 4 | hualmay
# Processing Record 37 of Set 4 | maraa
# Processing Record 38 of Set 4 | severodvinsk
# Processing Record 39 of Set 4 | hobart
# Processing Record 40 of Set 4 | vitina
# Processing Record 41 of Set 4 | zyryanka
# Processing Record 42 of Set 4 | ahipara
# Processing Record 43 of Set 4 | mandalgovi
# Processing Record 44 of Set 4 | phan thiet
# City not found... skipping...
# Processing Record 46 of Set 4 | murray bridge
# Processing Record 47 of Set 4 | todos santos
# City not found... skipping...
# Processing Record 49 of Set 4 | dali
# Processing Record 0 of Set 5 | urdoma
# Processing Record 1 of Set 5 | dungarpur
# Processing Record 2 of Set 5 | faanui
# Processing Record 3 of Set 5 | palatka
# Processing Record 4 of Set 5 | bucerias
# Processing Record 5 of Set 5 | inverell
# Processing Record 6 of Set 5 | ballina
# Processing Record 7 of Set 5 | puerto carreno
# Processing Record 8 of Set 5 | alice springs
# Processing Record 9 of Set 5 | pevek
# Processing Record 10 of Set 5 | salalah
# Processing Record 11 of Set 5 | trairi
# Processing Record 12 of Set 5 | harper
# Processing Record 13 of Set 5 | saskylakh
# Processing Record 14 of Set 5 | chuy
# Processing Record 15 of Set 5 | provideniya
# Processing Record 16 of Set 5 | coquimbo
# Processing Record 17 of Set 5 | lawrenceburg
# Processing Record 18 of Set 5 | olinda
# Processing Record 19 of Set 5 | cairns
# Processing Record 20 of Set 5 | buraydah
# Processing Record 21 of Set 5 | yaan
# City not found... skipping...
# Processing Record 23 of Set 5 | andros town
# Processing Record 24 of Set 5 | puerto del rosario
# Processing Record 25 of Set 5 | hervey bay
# Processing Record 26 of Set 5 | lavrentiya
# Processing Record 27 of Set 5 | margate
# Processing Record 28 of Set 5 | key west
# City not found... skipping...
# Processing Record 30 of Set 5 | nikolskoye
# Processing Record 31 of Set 5 | pasighat
# City not found... skipping...
# Processing Record 33 of Set 5 | mhango
# Processing Record 34 of Set 5 | ulladulla
# Processing Record 35 of Set 5 | mlonggo
# Processing Record 36 of Set 5 | saint george
# Processing Record 37 of Set 5 | borba
# Processing Record 38 of Set 5 | talnakh
# Processing Record 39 of Set 5 | wuhu
# Processing Record 40 of Set 5 | bhachau
# Processing Record 41 of Set 5 | burnie
# City not found... skipping...
# Processing Record 43 of Set 5 | salisbury
# Processing Record 44 of Set 5 | kiama
# Processing Record 45 of Set 5 | san cristobal
# Processing Record 46 of Set 5 | luwuk
# Processing Record 47 of Set 5 | seddon
# Processing Record 48 of Set 5 | richards bay
# Processing Record 49 of Set 5 | los llanos de aridane
# Processing Record 0 of Set 6 | fortuna
# City not found... skipping...
# Processing Record 2 of Set 6 | yulara
# Processing Record 3 of Set 6 | roros
# Processing Record 4 of Set 6 | matelandia
# Processing Record 5 of Set 6 | hammerfest
# Processing Record 6 of Set 6 | lata
# Processing Record 7 of Set 6 | aklavik
# City not found... skipping...
# City not found... skipping...
# Processing Record 10 of Set 6 | santa barbara
# Processing Record 11 of Set 6 | butaritari
# City not found... skipping...
# City not found... skipping...
# Processing Record 14 of Set 6 | bibai
# Processing Record 15 of Set 6 | port keats
# Processing Record 16 of Set 6 | keetmanshoop
# Processing Record 17 of Set 6 | zhaotong
# Processing Record 18 of Set 6 | nexo
# Processing Record 19 of Set 6 | maldonado
# Processing Record 20 of Set 6 | joao pinheiro
# City not found... skipping...
# Processing Record 22 of Set 6 | kalianget
# Processing Record 23 of Set 6 | atasu
# Processing Record 24 of Set 6 | abu zabad
# City not found... skipping...
# Processing Record 26 of Set 6 | ahualulco
# City not found... skipping...
# Processing Record 28 of Set 6 | aquiraz
# Processing Record 29 of Set 6 | benxi
# City not found... skipping...
# Processing Record 31 of Set 6 | torbay
# Processing Record 32 of Set 6 | kushima
# Processing Record 33 of Set 6 | buarcos
# City not found... skipping...
# Processing Record 35 of Set 6 | chapais
# Processing Record 36 of Set 6 | san patricio
# Processing Record 37 of Set 6 | ancud
# Processing Record 38 of Set 6 | porto novo
# Processing Record 39 of Set 6 | thompson
# Processing Record 40 of Set 6 | langham
# Processing Record 41 of Set 6 | cabo san lucas
# Processing Record 42 of Set 6 | pacific grove
# Processing Record 43 of Set 6 | cam ranh
# Processing Record 44 of Set 6 | port elizabeth
# City not found... skipping...
# Processing Record 46 of Set 6 | liberal
# City not found... skipping...
# Processing Record 48 of Set 6 | san clemente
# Processing Record 49 of Set 6 | kibaya
# Processing Record 0 of Set 7 | isabela
# Processing Record 1 of Set 7 | hinatuan
# Processing Record 2 of Set 7 | muncar
# Processing Record 3 of Set 7 | kahului
# Processing Record 4 of Set 7 | kavaratti
# Processing Record 5 of Set 7 | aksay
# Processing Record 6 of Set 7 | grafton
# Processing Record 7 of Set 7 | morgantown
# Processing Record 8 of Set 7 | narsaq
# Processing Record 9 of Set 7 | greensburg
# Processing Record 10 of Set 7 | puqi
# Processing Record 11 of Set 7 | shingu
# Processing Record 12 of Set 7 | puerto escondido
# Processing Record 13 of Set 7 | galveston
# Processing Record 14 of Set 7 | port blair
# Processing Record 15 of Set 7 | baykit
# Processing Record 42 of Set 8 | rauma
# City not found... skipping...
# Processing Record 44 of Set 8 | sivaki
# Processing Record 45 of Set 8 | davila
# Processing Record 46 of Set 8 | narsingi
# Processing Record 47 of Set 8 | sonamura
# Processing Record 48 of Set 8 | dubbo
# Processing Record 49 of Set 8 | atherton
# Processing Record 0 of Set 9 | rathenow
# City not found... skipping...
# Processing Record 2 of Set 9 | conakry
# Processing Record 3 of Set 9 | umea
# Processing Record 4 of Set 9 | erzin
# Processing Record 5 of Set 9 | naze
# City not found... skipping...
# Processing Record 7 of Set 9 | dingle
# Processing Record 8 of Set 9 | evensk
# Processing Record 9 of Set 9 | birao
# Processing Record 10 of Set 9 | martapura
# Processing Record 11 of Set 9 | tabou
# City not found... skipping...
# Processing Record 13 of Set 9 | sao lourenco do sul
# Processing Record 14 of Set 9 | banamba
# Processing Record 15 of Set 9 | shizunai
# Processing Record 16 of Set 9 | uyuni
# Processing Record 17 of Set 9 | roebourne
# Processing Record 18 of Set 9 | imeni poliny osipenko
# Processing Record 19 of Set 9 | bonoua
# Processing Record 20 of Set 9 | raton
# Processing Record 21 of Set 9 | rundu
# Processing Record 22 of Set 9 | kilindoni
# Processing Record 23 of Set 9 | agapovka
# Processing Record 24 of Set 9 | najran
# Processing Record 25 of Set 9 | cusuna
# Processing Record 26 of Set 9 | valparaiso
# Processing Record 27 of Set 9 | saint-pierre
# Processing Record 28 of Set 9 | kisangani
# Processing Record 29 of Set 9 | boca do acre
# Processing Record 30 of Set 9 | zhangjiakou
# Processing Record 31 of Set 9 | dunedin
# Processing Record 32 of Set 9 | villaviciosa
# Processing Record 33 of Set 9 | wuwei
# Processing Record 34 of Set 9 | tsabong
# Processing Record 35 of Set 9 | leningradskiy
# Processing Record 36 of Set 9 | ilhabela
# Processing Record 37 of Set 9 | houma
# Processing Record 38 of Set 9 | yatou
# Processing Record 39 of Set 9 | kanniyakumari
# City not found... skipping...
# Processing Record 41 of Set 9 | koulikoro
# Processing Record 42 of Set 9 | qujing
# Processing Record 43 of Set 9 | ketchikan
# Processing Record 44 of Set 9 | muana
# Processing Record 45 of Set 9 | mitsamiouli
# Processing Record 46 of Set 9 | arys
# Processing Record 47 of Set 9 | gimli
# Processing Record 48 of Set 9 | zinder
# Processing Record 49 of Set 9 | luau
# Processing Record 0 of Set 10 | ust-ilimsk
# Processing Record 1 of Set 10 | nishihara
# Processing Record 2 of Set 10 | mecca
# Processing Record 3 of Set 10 | rovaniemi
# Processing Record 4 of Set 10 | nuuk
# Processing Record 5 of Set 10 | ludvika
# Processing Record 6 of Set 10 | chinhoyi
# Processing Record 7 of Set 10 | kuopio
# City not found... skipping...
# Processing Record 9 of Set 10 | makakilo city
# City not found... skipping...
# Processing Record 11 of Set 10 | rocha
# Processing Record 12 of Set 10 | borodino
# City not found... skipping...
# Processing Record 14 of Set 10 | mindelo
# Processing Record 15 of Set 10 | batagay-alyta
# Processing Record 16 of Set 10 | naraina
# Processing Record 17 of Set 10 | thurso
# Processing Record 18 of Set 10 | caravelas
# Processing Record 19 of Set 10 | digoin
# Processing Record 20 of Set 10 | imbituba
# Processing Record 21 of Set 10 | aborlan
# Processing Record 22 of Set 10 | portland
# Processing Record 23 of Set 10 | geraldton
# City not found... skipping...
# Processing Record 25 of Set 10 | nome
# City not found... skipping...
# Processing Record 27 of Set 10 | san vicente de canete
# City not found... skipping...
# Processing Record 29 of Set 10 | henties bay
# Processing Record 30 of Set 10 | puerto narino
# Processing Record 31 of Set 10 | lagos
# Processing Record 32 of Set 10 | broken hill
# City not found... skipping...
# Processing Record 34 of Set 10 | contai
# Processing Record 35 of Set 10 | shimoda
# Processing Record 36 of Set 10 | xai-xai
# Processing Record 37 of Set 10 | manokwari
# Processing Record 38 of Set 10 | flin flon
# Processing Record 39 of Set 10 | bilibino
# Processing Record 40 of Set 10 | fairbanks
# Processing Record 41 of Set 10 | watertown
# Processing Record 42 of Set 10 | grants
# Processing Record 43 of Set 10 | albanel
# City not found... skipping...
# Processing Record 45 of Set 10 | quatre cocos
# City not found... skipping...
# City not found... skipping...
# Processing Record 48 of Set 10 | abu kamal
# Processing Record 49 of Set 10 | xingyi
# Processing Record 0 of Set 11 | ponta delgada
# Processing Record 1 of Set 11 | codrington
# Processing Record 2 of Set 11 | vostok
# Processing Record 3 of Set 11 | west plains
# Processing Record 4 of Set 11 | lebedinyy
# Processing Record 5 of Set 11 | kuandian
# Processing Record 6 of Set 11 | port hardy
# Processing Record 7 of Set 11 | chino valley
# Processing Record 8 of Set 11 | manavalakurichi
# Processing Record 9 of Set 11 | lodwar
# Processing Record 10 of Set 11 | camaqua
# Processing Record 11 of Set 11 | vao
# Processing Record 12 of Set 11 | wanning
# Processing Record 13 of Set 11 | san jose
# Processing Record 14 of Set 11 | avera
# Processing Record 15 of Set 11 | labuhan
# Processing Record 16 of Set 11 | hay river
# Processing Record 17 of Set 11 | timizart
# Processing Record 18 of Set 11 | padang
# Processing Record 19 of Set 11 | cefa
# Processing Record 20 of Set 11 | seidu
# Processing Record 21 of Set 11 | mamallapuram
# Processing Record 22 of Set 11 | kurilsk
# Processing Record 23 of Set 11 | nadym
# City not found... skipping...
# Processing Record 25 of Set 11 | malpe
# Processing Record 26 of Set 11 | inirida
# Processing Record 27 of Set 11 | saquarema
# Processing Record 28 of Set 11 | dukat
# Processing Record 29 of Set 11 | sola
# Processing Record 30 of Set 11 | ftelia
# Processing Record 31 of Set 11 | ondjiva
# Processing Record 32 of Set 11 | havre-saint-pierre
# Processing Record 33 of Set 11 | gijon
# Processing Record 34 of Set 11 | mkushi
# Processing Record 35 of Set 11 | ayr
# Processing Record 36 of Set 11 | iskateley
# City not found... skipping...
# Processing Record 38 of Set 11 | huilong
# Processing Record 39 of Set 11 | santo antonio do ica
# Processing Record 40 of Set 11 | hovd
# Processing Record 41 of Set 11 | mae hong son
# Processing Record 42 of Set 11 | namibe
# Processing Record 43 of Set 11 | cerritos
# Processing Record 44 of Set 11 | jacareacanga
# Processing Record 45 of Set 11 | ambon
# Processing Record 46 of Set 11 | manakara
# Processing Record 47 of Set 11 | khlung
# Processing Record 48 of Set 11 | constitucion
# Processing Record 49 of Set 11 | aksarka
# Processing Record 0 of Set 12 | ekuvukeni
# Processing Record 1 of Set 12 | zhigansk
# Processing Record 2 of Set 12 | nanakuli
# Processing Record 3 of Set 12 | quang ngai
# Processing Record 4 of Set 12 | ponnani
# Processing Record 5 of Set 12 | bad doberan
# Processing Record 6 of Set 12 | fort-shevchenko
# Processing Record 7 of Set 12 | bathgate
# Processing Record 8 of Set 12 | constantine
# Processing Record 9 of Set 12 | malaya serdoba
# Processing Record 10 of Set 12 | barhi
# Processing Record 11 of Set 12 | antwerp
# Processing Record 12 of Set 12 | cherepanovo
# Processing Record 13 of Set 12 | kargil
# Processing Record 14 of Set 12 | russell
# City not found... skipping...
# Processing Record 16 of Set 12 | rawson
# Processing Record 17 of Set 12 | kaili
# Processing Record 18 of Set 12 | entre rios
# Processing Record 19 of Set 12 | sobolevo
# City not found... skipping...
# Processing Record 21 of Set 12 | kenai
# Processing Record 22 of Set 12 | newport
# Processing Record 23 of Set 12 | elko
# Processing Record 24 of Set 12 | alugan
# City not found... skipping...
# Processing Record 26 of Set 12 | oistins
# Processing Record 27 of Set 12 | bowen
# Processing Record 28 of Set 12 | mantua
# City not found... skipping...
# Processing Record 30 of Set 12 | abnub
# Processing Record 31 of Set 12 | natal
# Processing Record 32 of Set 12 | high level
# Processing Record 33 of Set 12 | tianpeng
# Processing Record 34 of Set 12 | san cosme y damian
# Processing Record 35 of Set 12 | charters towers
# City not found... skipping...
# Processing Record 37 of Set 12 | wade hampton
# Processing Record 38 of Set 12 | daru
# Processing Record 39 of Set 12 | hobyo
# Processing Record 40 of Set 12 | ust-omchug
# Processing Record 41 of Set 12 | chumikan
# Processing Record 42 of Set 12 | naliya
# Processing Record 43 of Set 12 | nabire
# City not found... skipping...
# Processing Record 45 of Set 12 | la baule-escoublac
# Processing Record 46 of Set 12 | narvik
# Processing Record 47 of Set 12 | limon
# City not found... skipping...
# Processing Record 49 of Set 12 | lungi
# Processing Record 0 of Set 13 | vanavara
# Processing Record 1 of Set 13 | bubaque
# Processing Record 2 of Set 13 | emba
# City not found... skipping...
# Processing Record 4 of Set 13 | beidao
# Processing Record 5 of Set 13 | wigston
# Processing Record 6 of Set 13 | havoysund
# Processing Record 7 of Set 13 | clyde river
# Processing Record 8 of Set 13 | fairlie
# Processing Record 9 of Set 13 | turbat
# Processing Record 10 of Set 13 | umm lajj
# Processing Record 11 of Set 13 | duns
# Processing Record 12 of Set 13 | lamar
# Processing Record 13 of Set 13 | dorogobuzh
# Processing Record 14 of Set 13 | hirado
# Processing Record 15 of Set 13 | baker city
# Processing Record 16 of Set 13 | conceicao do coite
# City not found... skipping...
# Processing Record 18 of Set 13 | naryan-mar
# Processing Record 19 of Set 13 | vardo
# Processing Record 20 of Set 13 | tura
# Processing Record 21 of Set 13 | ler
# Processing Record 22 of Set 13 | rosetta
# Processing Record 23 of Set 13 | bereda
# Processing Record 24 of Set 13 | praia da vitoria
# Processing Record 25 of Set 13 | hokitika
# Processing Record 26 of Set 13 | lompoc
# Processing Record 27 of Set 13 | awjilah
# Processing Record 28 of Set 13 | lokosovo
# Processing Record 29 of Set 13 | tymovskoye
# City not found... skipping...
# Processing Record 31 of Set 13 | doctor juan manuel frutos
# Processing Record 32 of Set 13 | narasapur
# Processing Record 33 of Set 13 | kamloops
# Processing Record 34 of Set 13 | muroto
# Processing Record 35 of Set 13 | san carlos
# Processing Record 36 of Set 13 | udomlya
# ----------------------------
# Data Retrieval Complete
# ----------------------------

# %%
cities_df.head()
# Out:
#          City Cloudiness Country        Date Humidity    Lat     Lng Max Temp  \
# 0  vila velha         75      BR  1547740800       74  -3.71   -38.6       30
# 1         gat          0      SN  1547742600       23  14.69  -16.54       29
# 2   busselton          0      AU  1547743938      100 -33.64  115.35    15.46
# 3   ilulissat         75      GL  1547740200       71  69.22   -51.1      -13
# 4        gizo         75      IL  1547742000       71   31.8   34.94       15
#
#   Wind Speed
# 0        6.2
# 1        7.2
# 2       5.71
# 3          1
# 4        4.1

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
Latplot=pd.to_numeric(cities_df.Lat)
Templot=pd.to_numeric(cities_df['Max Temp'])
fahrplot = (Templot * 1.8) + 32
plt.scatter(Latplot,fahrplot,edgecolor='k')
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.title("Latitude vs. Max Temperatue (12/25/2018)")
# Out:
# Text(0.5,1,'Latitude vs. Max Temperatue (12/25/2018)')

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
Latplot=pd.to_numeric(cities_df.Lat)
Humplot=pd.to_numeric(cities_df['Humidity'])
plt.scatter(Latplot,Humplot,edgecolor='k')
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("Latitude vs. Humidity (12/25/2018)")
# Out:
# Text(0.5,1,'Latitude vs. Humidity (12/25/2018)')

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
Latplot=pd.to_numeric(cities_df.Lat)
Cloudplot=pd.to_numeric(cities_df['Cloudiness'])
plt.scatter(Latplot,Cloudplot,edgecolor='k')
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("Latitude vs. Cloudiness (12/25/2018)")
# Out:
# Text(0.5,1,'Latitude vs. Cloudiness (12/25/2018)')

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
Latplot=pd.to_numeric(cities_df.Lat)
Windplot=pd.to_numeric(cities_df['Wind Speed'])
plt.scatter(Latplot,Windplot,edgecolor='k')
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title("Latitude vs. Wind Speed (12/25/2018)")
# Out:
# Text(0.5,1,'Latitude vs. Wind Speed (12/25/2018)')
